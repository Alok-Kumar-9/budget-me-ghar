# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('/content/MagicBricks.csv')
df
# Out:
#          Area  BHK  Bathroom  ...   Transaction           Type  Per_Sqft
# 0       800.0    3       2.0  ...  New_Property  Builder_Floor       NaN
# 1       750.0    2       2.0  ...  New_Property      Apartment    6667.0
# 2       950.0    2       2.0  ...        Resale      Apartment    6667.0
# 3       600.0    2       2.0  ...        Resale  Builder_Floor    6667.0
# 4       650.0    2       2.0  ...  New_Property  Builder_Floor    6667.0
# ...       ...  ...       ...  ...           ...            ...       ...
# 1254   4118.0    4       5.0  ...  New_Property  Builder_Floor   12916.0
# 1255   1050.0    3       2.0  ...        Resale  Builder_Floor   12916.0
# 1256    875.0    3       3.0  ...  New_Property  Builder_Floor   12916.0
# 1257    990.0    2       2.0  ...        Resale  Builder_Floor   12916.0
# 1258  11050.0    3       3.0  ...  New_Property  Builder_Floor   12916.0
#
# [1259 rows x 11 columns]

# %%
#in real life example locality matters...so try to incoporate this feature in your dataset...

X = df.drop(['Per_Sqft','Price','Locality'],axis='columns')
Y=df['Price']

# %%
X
# Out:
#          Area  BHK  Bathroom  ...         Status   Transaction           Type
# 0       800.0    3       2.0  ...  Ready_to_move  New_Property  Builder_Floor
# 1       750.0    2       2.0  ...  Ready_to_move  New_Property      Apartment
# 2       950.0    2       2.0  ...  Ready_to_move        Resale      Apartment
# 3       600.0    2       2.0  ...  Ready_to_move        Resale  Builder_Floor
# 4       650.0    2       2.0  ...  Ready_to_move  New_Property  Builder_Floor
# ...       ...  ...       ...  ...            ...           ...            ...
# 1254   4118.0    4       5.0  ...  Ready_to_move  New_Property  Builder_Floor
# 1255   1050.0    3       2.0  ...  Ready_to_move        Resale  Builder_Floor
# 1256    875.0    3       3.0  ...  Ready_to_move  New_Property  Builder_Floor
# 1257    990.0    2       2.0  ...  Ready_to_move        Resale  Builder_Floor
# 1258  11050.0    3       3.0  ...  Ready_to_move  New_Property  Builder_Floor
#
# [1259 rows x 8 columns]

# %%
Y
# Out:
# 0        6500000
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
#           ...
# 1254    55000000
# 1255    12500000
# 1256    17500000
# 1257    11500000
# 1258    18500000
# Name: Price, Length: 1259, dtype: int64

# %%
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()
le4 = LabelEncoder()

X['Furnishing_n'] = le1.fit_transform(X['Furnishing'])
X['Status_n'] = le2.fit_transform(X['Status'])
X['Transaction_n'] = le3.fit_transform(X['Transaction'])
X['Type_n'] = le4.fit_transform(X['Type'])

X.drop(['Furnishing', 'Status', 'Transaction', 'Type'], axis='columns', inplace=True)

X
# Out:
#          Area  BHK  Bathroom  ...  Status_n  Transaction_n  Type_n
# 0       800.0    3       2.0  ...         1              0       1
# 1       750.0    2       2.0  ...         1              0       0
# 2       950.0    2       2.0  ...         1              1       0
# 3       600.0    2       2.0  ...         1              1       1
# 4       650.0    2       2.0  ...         1              0       1
# ...       ...  ...       ...  ...       ...            ...     ...
# 1254   4118.0    4       5.0  ...         1              0       1
# 1255   1050.0    3       2.0  ...         1              1       1
# 1256    875.0    3       3.0  ...         1              0       1
# 1257    990.0    2       2.0  ...         1              1       1
# 1258  11050.0    3       3.0  ...         1              0       1
#
# [1259 rows x 8 columns]

# %%
X.isnull().sum()
# Out:
# Area              0
# BHK               0
# Bathroom          2
# Parking          33
# Furnishing_n      0
# Status_n          0
# Transaction_n     0
# Type_n            0
# dtype: int64

# %%
Y.isnull().sum()
# Out:
# 0

# %%
import math

rr = math.floor(X['Bathroom'].mean(skipna=True))
rw = math.floor(X['Parking'].mean(skipna=True))

print(rr , rw)
# Out:
# 2 1

# %%
X.fillna(value={'Bathroom':rr , 'Parking':rw}, axis='rows', inplace=True)
X
# Out:
#          Area  BHK  Bathroom  ...  Status_n  Transaction_n  Type_n
# 0       800.0    3       2.0  ...         1              0       1
# 1       750.0    2       2.0  ...         1              0       0
# 2       950.0    2       2.0  ...         1              1       0
# 3       600.0    2       2.0  ...         1              1       1
# 4       650.0    2       2.0  ...         1              0       1
# ...       ...  ...       ...  ...       ...            ...     ...
# 1254   4118.0    4       5.0  ...         1              0       1
# 1255   1050.0    3       2.0  ...         1              1       1
# 1256    875.0    3       3.0  ...         1              0       1
# 1257    990.0    2       2.0  ...         1              1       1
# 1258  11050.0    3       3.0  ...         1              0       1
#
# [1259 rows x 8 columns]

# %%
X.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Parking          0
# Furnishing_n     0
# Status_n         0
# Transaction_n    0
# Type_n           0
# dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(n_estimators=150)
model.fit(X_train , Y_train)
# Out:
# RandomForestRegressor(n_estimators=150)

# %%
predicted = model.predict(X_test)

# %%
predicted
# Out:
# array([1.94100921e+07, 2.44300000e+07, 6.13844444e+06, 5.23500000e+07,
#        3.24306667e+06, 2.24440000e+07, 6.28285000e+07, 1.02325000e+08,
#        3.59220000e+06, 2.16448889e+07, 1.20354000e+07, 2.72642222e+06,
#        3.05400000e+07, 6.79695556e+06, 8.22875556e+06, 2.96456000e+07,
#        2.88658333e+06, 1.35136667e+07, 5.79292593e+06, 4.16158016e+07,
#        3.98600000e+06, 1.22784444e+07, 1.57382222e+07, 2.78153889e+06,
#        1.88330333e+07, 3.47728333e+07, 2.62971667e+07, 4.42098889e+07,
#        1.04076000e+07, 4.17766667e+06, 6.03262381e+06, 6.80856667e+06,
#        1.51376111e+07, 5.26343333e+06, 1.49540000e+07, 3.00697778e+06,
#        6.49814167e+07, 7.05010000e+06, 1.11526111e+07, 2.02701111e+07,
#        1.01637000e+07, 4.62088889e+06, 2.69866429e+07, 5.13075873e+07,
#        1.74051667e+07, 1.43851111e+07, 2.79880000e+07, 1.02604111e+07,
#        8.94959894e+06, 6.68513333e+07, 5.69372222e+07, 5.38215238e+07,
#        7.24373333e+06, 1.94730000e+07, 6.89573333e+06, 9.59620000e+06,
#        1.33328333e+07, 1.40749833e+07, 2.57940847e+07, 5.61222063e+06,
#        6.80856667e+06, 5.10913333e+06, 4.75026667e+06, 1.42417778e+07,
#        1.58848889e+07, 6.91778095e+06, 5.69717778e+06, 1.10330000e+08,
#        7.74960000e+06, 6.78543333e+06, 6.32410476e+06, 3.89686667e+06,
#        3.35623214e+07, 2.38877778e+06, 9.10165079e+06, 6.64171111e+06,
#        3.96272222e+06, 2.34366667e+06, 5.55241667e+07, 1.75751111e+07,
#        3.87842222e+07, 6.14711111e+06, 6.47291111e+06, 8.66853333e+06,
#        3.14415556e+07, 7.36727778e+07, 7.59734949e+06, 1.78651111e+07,
#        1.77159841e+07, 4.09733333e+06, 1.78027143e+07, 2.31316667e+07,
#        8.86799921e+06, 2.89634444e+07, 1.05596444e+07, 1.59605873e+07,
#        6.03262381e+06, 2.79253333e+06, 4.36707619e+07, 1.35227778e+07,
#        4.14516667e+06, 7.33338889e+06, 6.00535833e+07, 3.23168889e+07,
